# %% [markdown]
# # Sc-candida data
# Convert data to python formats and filter genes

# %% [markdown]
# ## 0. Loading the libraries

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import scanpy as sc
import numpy as np
import scipy as sp
import pandas as pd

# %matplotlib inline
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import seaborn as sb
sb.set_context('notebook')
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib import colors
plt.rcParams['figure.figsize']=(8,8) #rescale figures
plt.rcParams.update({'figure.max_open_warning': 0})


from gprofiler import gprofiler

#import sys


import scprep
from umap import UMAP
import graphtools as gt
import meld
import magic

# %%
import rpy2
print(rpy2.__version__)
# Out:
# 3.4.2

# %%
# Ignore R warning messages
# Note: this can be commented out to get more verbose R output
import rpy2.rinterface_lib.callbacks
import logging
rpy2.rinterface_lib.callbacks.logger.setLevel(logging.ERROR)

# Automatically convert rpy2 outputs to pandas dataframes
import rpy2.robjects as ro

from rpy2.robjects import pandas2ri
pandas2ri.activate()

from rpy2.robjects import numpy2ri
numpy2ri.activate()

import anndata2ri
anndata2ri.activate()

# %reload_ext rpy2.ipython

sc.settings.verbosity = 3
#sc.set_figure_params(dpi=200, dpi_save=300)
sc.logging.print_versions()

import scvi
# Out:
# WARNING: If you miss a compact list, please try `print_header`!
# -----
# anndata     0.7.6
# scanpy      1.8.1
# sinfo       0.3.1
# -----
# PIL                 8.3.1
# anndata             0.7.6
# anndata2ri          0.0.0
# autoreload          NA
# backcall            0.2.0
# beta_ufunc          NA
# binom_ufunc         NA
# brotli              NA
# certifi             2021.05.30
# cffi                1.14.6
# chardet             4.0.0
# charset_normalizer  2.0.0
# colorama            0.4.4
# concurrent          NA
# cycler              0.10.0
# cython_runtime      NA
# dateutil            2.8.2
# decorator           4.4.2
# defusedxml          0.7.1
# deprecated          1.2.12
# dunamai             1.6.0
# encodings           NA
# future              0.18.2
# genericpath         NA
# get_version         3.5
# google              NA
# gprofiler           1.0.0
# graphtools          1.5.2
# h5py                3.3.0
# idna                3.2
# igraph              0.9.6
# ipykernel           6.1.0
# ipython_genutils    0.2.0
# ipywidgets          7.6.3
# jedi                0.18.0
# jinja2              3.0.1
# joblib              1.0.1
# kiwisolver          1.3.1
# leidenalg           0.8.7
# llvmlite            0.36.0
# magic               3.0.0
# markupsafe          2.0.1
# matplotlib          3.4.2
# matplotlib_inline   NA
# meld                0.5.0
# mpl_toolkits        NA
# natsort             7.1.1
# nbinom_ufunc        NA
# ntpath              NA
# numba               0.53.1
# numexpr             2.7.3
# numpy               1.21.1
# opcode              NA
# packaging           20.9
# pandas              1.3.1
# parso               0.8.2
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# posixpath           NA
# prompt_toolkit      3.0.19
# ptyprocess          0.7.0
# pycparser           2.20
# pydoc_data          NA
# pyexpat             NA
# pygments            2.9.0
# pygsp               0.5.1
# pynndescent         0.5.4
# pyparsing           2.4.7
# pytz                2021.1
# requests            2.26.0
# rpy2                3.4.2
# scanpy              1.8.1
# scipy               1.7.1
# scprep              1.1.0
# seaborn             0.11.1
# sinfo               0.3.1
# sitecustomize       NA
# six                 1.16.0
# sklearn             0.24.2
# socks               1.7.1
# sphinxcontrib       NA
# sre_compile         NA
# sre_constants       NA
# sre_parse           NA
# statsmodels         0.12.2
# storemagic          NA
# tables              3.6.1
# tasklogger          1.1.0
# texttable           1.6.4
# threadpoolctl       2.2.0
# tornado             6.1
# traitlets           5.0.5
# typing_extensions   NA
# tzlocal             NA
# umap                0.5.1
# urllib3             1.26.6
# wcwidth             0.2.5
# wrapt               1.12.1
# yaml                5.4.1
# zmq                 22.2.1
# -----
# IPython             7.26.0
# jupyter_client      6.1.12
# jupyter_core        4.7.1
# notebook            6.4.3
# -----
# Python 3.9.6 | packaged by conda-forge | (default, Jul 11 2021, 03:39:48) [GCC 9.3.0]
# Linux-4.15.0-142-generic-x86_64-with-glibc2.27
# 32 logical CPU cores, x86_64
# -----
# Session information updated at 2022-05-02 13:55

# %%
# %%R
# .libPaths(R.home("~/anaconda3/envs/scvi-env/lib/R/library"))
# library(SingleCellExperiment)
# library(here)

# %% [markdown]
# <a id="Reading"></a>

# %% [markdown]
# ## 1. Reading in the data
#
# Here we are loading the gene x cell count matrix after cell filtering using emptyDrops (exp02-emptyDrops_sceQC)

# %%
# %%R -o adata
#
# adata = readRDS(here("data", "data02-emptyDrops_sceQC", "filtered-sce.rds"))
# adata
# Out:
# class: SingleCellExperiment
# dim: 6169 18854
# metadata(0):
# assays(2): X logcounts
# rownames(6169): CTA2 TUP1 ... CR00650WA CR00720WA
# rowData names(0):
# colnames(18854): CSP_2_1_FALSE_CGTTTGCAGCTT CSP_2_1_FALSE_GATATCAGGTGC
#   ... UT_0_3_FALSE_CGCGTGCCAGGC UT_0_3_FALSE_GTGGGTTAGCTT
# colData names(15): orig.ident nCount_RNA ... subsets_Ribo_percent total
# reducedDimNames(0):
# altExpNames(0):

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 18854 × 6169
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'drug', 'day', 'batch', 'nruns', 'drug_day', 'ident', 'sum', 'detected', 'subsets_Ribo_sum', 'subsets_Ribo_detected', 'subsets_Ribo_percent', 'total'
#     layers: 'logcounts'

# %%
# Annotate the data sets
print(adata.obs['orig.ident'].value_counts())
print('')
print(adata.obs['drug'].value_counts())
print('')
print(adata.obs['nruns'].value_counts())
print('')
# Out:
# UT_0_1_FALSE      2736
# FCZ_6_3_FALSE     2483
# RAPA_2_2_FALSE    2460
# FCZ_2_2_FALSE     2444
# CSP_2_1_FALSE     2075
# UT_0_3_FALSE      2050
# FCZ_3_2_FALSE     1616
# FCZ_2_1_FALSE      948
# FCZ_3_3_FALSE      908
# FCZ_3_1_FALSE      858
# UT_0_2_FALSE       276
# Name: orig.ident, dtype: int64
#
# FCZ     9257
# UT      5062
# RAPA    2460
# CSP     2075
# Name: drug, dtype: int64
#
# 3.0    12237
# 2.0     6617
# Name: nruns, dtype: int64

# %%
# Checking the total size of the data set
adata.shape
# Out:
# (18854, 6169)

# %% [markdown]
# <a id="Preprocessing"></a>

# %% [markdown]
# ## 2. Filtering genes

# %% [markdown]
# <a id="QC"></a>

# %%
adata.X
# Out:
# <18854x6169 sparse matrix of type '<class 'numpy.float32'>'
# 	with 1768466 stored elements in Compressed Sparse Row format>

# %%
adata.obs['nCount_RNA']
# Out:
# CSP_2_1_FALSE_CGTTTGCAGCTT    346.0
# CSP_2_1_FALSE_GATATCAGGTGC    486.0
# CSP_2_1_FALSE_CTGCGCTCTAAA    414.0
# CSP_2_1_FALSE_GGGTATTCATAT    366.0
# CSP_2_1_FALSE_AAGCTAGGACGC    286.0
#                               ...
# UT_0_3_FALSE_CCACTGGATTCC      81.0
# UT_0_3_FALSE_GCATTTGATGAT      83.0
# UT_0_3_FALSE_AGGGGCGTAGAT      82.0
# UT_0_3_FALSE_CGCGTGCCAGGC      85.0
# UT_0_3_FALSE_GTGGGTTAGCTT      90.0
# Name: nCount_RNA, Length: 18854, dtype: float64

# %%
# Quality control - calculate QC covariates
adata.obs['n_counts'] = adata.X.sum(1)
adata.obs['log_counts'] = np.log(adata.X.sum(1))
adata.obs['n_genes'] = (adata.X > 0).sum(1)

# %%
t1 = sc.pl.violin(adata, 'n_counts', groupby='orig.ident', size=2, rotation = 90, log=True, cut=0,save="raw_counts.png")
# Out:
# /home/vanessa.d/anaconda3/envs/scvi-env/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'orig.ident' as categorical
# /home/vanessa.d/anaconda3/envs/scvi-env/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'drug' as categorical
# /home/vanessa.d/anaconda3/envs/scvi-env/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'day' as categorical
# /home/vanessa.d/anaconda3/envs/scvi-env/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'batch' as categorical
# /home/vanessa.d/anaconda3/envs/scvi-env/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'drug_day' as categorical
# WARNING: saving figure to file figures/violinraw_counts.png

# %%
t1 = sc.pl.violin(adata, 'n_genes', groupby='orig.ident', size=2, rotation = 90, log=True, cut=0,save="raw_genes.png")
# Out:
# WARNING: saving figure to file figures/violinraw_genes.png

# %%
# Filter cells according to identified QC thresholds:
print('Total number of cells: {:d}'.format(adata.n_obs))

sc.pp.filter_cells(adata, min_counts = 10)
print('Number of cells after min count filter: {:d}'.format(adata.n_obs))

sc.pp.filter_cells(adata, max_counts = 2000)
print('Number of cells after max count filter: {:d}'.format(adata.n_obs))

#adata = adata[adata.obs['subsets_Ribo_percent'] < 0.70]
#print('Number of cells after ribo filter: {:d}'.format(adata.n_obs))

sc.pp.filter_cells(adata, min_genes = 10)
print('Number of cells after gene filter: {:d}'.format(adata.n_obs))
# Out:
# Total number of cells: 18854
# Number of cells after min count filter: 18854
# Number of cells after max count filter: 18854
# Number of cells after gene filter: 18854

# %%
# Annotate the data sets
print(adata.obs['orig.ident'].value_counts())
print('')
print(adata.obs['drug'].value_counts())
print('')
print(adata.obs['nruns'].value_counts())
print('')
# Out:
# UT_0_1_FALSE      2736
# FCZ_6_3_FALSE     2483
# RAPA_2_2_FALSE    2460
# FCZ_2_2_FALSE     2444
# CSP_2_1_FALSE     2075
# UT_0_3_FALSE      2050
# FCZ_3_2_FALSE     1616
# FCZ_2_1_FALSE      948
# FCZ_3_3_FALSE      908
# FCZ_3_1_FALSE      858
# UT_0_2_FALSE       276
# Name: orig.ident, dtype: int64
#
# FCZ     9257
# UT      5062
# RAPA    2460
# CSP     2075
# Name: drug, dtype: int64
#
# 3.0    12237
# 2.0     6617
# Name: nruns, dtype: int64

# %%
#Filter genes:
print('Total number of genes: {:d}'.format(adata.n_vars))

# Min 20 cells - filters out 0 count genes
sc.pp.filter_genes(adata, min_cells=20)
print('Number of genes after gene filter: {:d}'.format(adata.n_vars))
# Out:
# Total number of genes: 6169
# filtered out 892 genes that are detected in less than 20 cells
# Number of genes after gene filter: 5277

# %% [markdown]
# The filtering is performed based on the thresholds we identified from the QC plots. Genes are also filtered if they are not detected in at least 20 cells. This reduces the dimensions of the matrix by removing 0 count genes and genes which are not sufficiently informative of the dataset.

# %%
# Annotate the data sets
print(adata.obs['orig.ident'].value_counts())
print('')
print(adata.obs['drug'].value_counts())
print('')
# Out:
# UT_0_1_FALSE      2736
# FCZ_6_3_FALSE     2483
# RAPA_2_2_FALSE    2460
# FCZ_2_2_FALSE     2444
# CSP_2_1_FALSE     2075
# UT_0_3_FALSE      2050
# FCZ_3_2_FALSE     1616
# FCZ_2_1_FALSE      948
# FCZ_3_3_FALSE      908
# FCZ_3_1_FALSE      858
# UT_0_2_FALSE       276
# Name: orig.ident, dtype: int64
#
# FCZ     9257
# UT      5062
# RAPA    2460
# CSP     2075
# Name: drug, dtype: int64

# %%
adata.obs.head()
# Out:
#                                orig.ident  nCount_RNA  nFeature_RNA drug day  \
# CSP_2_1_FALSE_CGTTTGCAGCTT  CSP_2_1_FALSE       346.0           132  CSP   2
# CSP_2_1_FALSE_GATATCAGGTGC  CSP_2_1_FALSE       486.0           177  CSP   2
# CSP_2_1_FALSE_CTGCGCTCTAAA  CSP_2_1_FALSE       414.0           170  CSP   2
# CSP_2_1_FALSE_GGGTATTCATAT  CSP_2_1_FALSE       366.0           155  CSP   2
# CSP_2_1_FALSE_AAGCTAGGACGC  CSP_2_1_FALSE       286.0           131  CSP   2
#
#                            batch  nruns drug_day          ident    sum  \
# CSP_2_1_FALSE_CGTTTGCAGCTT     1    2.0    CSP_2  CSP_2_1_FALSE  346.0
# CSP_2_1_FALSE_GATATCAGGTGC     1    2.0    CSP_2  CSP_2_1_FALSE  486.0
# CSP_2_1_FALSE_CTGCGCTCTAAA     1    2.0    CSP_2  CSP_2_1_FALSE  414.0
# CSP_2_1_FALSE_GGGTATTCATAT     1    2.0    CSP_2  CSP_2_1_FALSE  366.0
# CSP_2_1_FALSE_AAGCTAGGACGC     1    2.0    CSP_2  CSP_2_1_FALSE  286.0
#
#                             detected  subsets_Ribo_sum  subsets_Ribo_detected  \
# CSP_2_1_FALSE_CGTTTGCAGCTT       132             163.0                     42
# CSP_2_1_FALSE_GATATCAGGTGC       177             227.0                     49
# CSP_2_1_FALSE_CTGCGCTCTAAA       170             199.0                     57
# CSP_2_1_FALSE_GGGTATTCATAT       155             184.0                     52
# CSP_2_1_FALSE_AAGCTAGGACGC       131             136.0                     43
#
#                             subsets_Ribo_percent  total  n_counts  log_counts  \
# CSP_2_1_FALSE_CGTTTGCAGCTT             47.109827  346.0     346.0    5.846439
# CSP_2_1_FALSE_GATATCAGGTGC             46.707819  486.0     486.0    6.186209
# CSP_2_1_FALSE_CTGCGCTCTAAA             48.067633  414.0     414.0    6.025866
# CSP_2_1_FALSE_GGGTATTCATAT             50.273224  366.0     366.0    5.902633
# CSP_2_1_FALSE_AAGCTAGGACGC             47.552448  286.0     286.0    5.655992
#
#                             n_genes
# CSP_2_1_FALSE_CGTTTGCAGCTT      132
# CSP_2_1_FALSE_GATATCAGGTGC      177
# CSP_2_1_FALSE_CTGCGCTCTAAA      170
# CSP_2_1_FALSE_GGGTATTCATAT      155
# CSP_2_1_FALSE_AAGCTAGGACGC      131

# %%
np.mean(adata.obs['n_counts'])
# Out:
# 184.21263

# %%
max(adata.obs['n_counts'])
# Out:
# 1984.0

# %%
t1 = sc.pl.violin(adata, 'n_counts', groupby='orig.ident', size=2, rotation = 90, log=True, cut=0)

# %%
t1 = sc.pl.violin(adata, 'n_genes', groupby='orig.ident', size=2, rotation = 90, log=True, cut=0)

# %%
np.mean(adata.obs['n_genes'])
# Out:
# 93.79792086559881

# %%
max(adata.obs['n_genes'])
# Out:
# 825

# %% [markdown]
# ## 3. Save anndata

# %%
adata.obs["nFeature_RNA"] = adata.obs["nFeature_RNA"].astype(int)
adata.obs["detected"] = adata.obs["detected"].astype(int)
adata.obs["subsets_Ribo_detected"] = adata.obs["subsets_Ribo_detected"].astype(float)
adata.write('../../data/data03-scvi/finalall-adata.h5ad')

# %%
adata.obs.to_csv("../../data/data03-scvi/finalall-adjLogcounts_labels.csv")
t=adata.X.toarray()
pd.DataFrame(data=t, index=adata.obs_names, columns=adata.var_names).to_csv('../../data/data03-scvi/finalall_raw.csv')
